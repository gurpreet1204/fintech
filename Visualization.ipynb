# %%
#line Plot

import yfinance as yf
import matplotlib.pyplot as plt
# Step 1: Get historical price data for NIFTY index (^NSEI) from Yahoo Finance
ticker = '^NSEI' # Ticker symbol for NIFTY index
start_date = '2023-01-01'
end_date = '2024-01-01'
nifty_data = yf.download(ticker, start=start_date, end=end_date)
# Step 2: Generate line plot of closing prices
plt.figure(figsize=(10, 6)) # Set figure size
plt.plot(nifty_data.index, nifty_data['Close'], color='blue') # Plot closing prices
plt.title('NIFTY Index - Closing Prices') # Set title
plt.xlabel('Date') # Set x-axis label
plt.ylabel('Price') # Set y-axis label
plt.grid(True) # Enable grid
plt.show() # Display plot
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import seaborn as sns
#pair plot
tickers=['^NSEI','RELIANCE.NS']
start_date='2023-01-01'
end_date='2024-01-01'
stock_data=yf.download(tickers,start=start_date,end=end_date)['Close']

#Generate Pair Plot
sns.pairplot(stock_data)
plt.show()
# Out:
# [*********************100%%**********************]  2 of 2 completed
# C:\Users\gurpr\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Distribution Plot
ticker='^NSEI'
start_date='2023-01-01'
end_date='2024-01-01'
nift_data=yf.download(ticker,start=start_date,end=end_date)['Close']

sns.displot(nift_data)
plt.title('Distribution of Nifty Closing Prices')
plt.xlabel('Closing price')
plt.ylabel('Density')
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\gurpr\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Moving Avg Plot

#historical Nifty data
#nift_data

window=50
moving_avg=nift_data.rolling(window=window).mean()

plt.figure(figsize=(10,6))
plt.plot(nift_data.index,nift_data,label="NIFTY INDEX",color='Blue')
plt.plot(moving_avg.index,moving_avg,label=f'{window}-Day Moving Avg',color='red')
plt.title(f'NIFTY Index -{window} - Day Avg ')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
